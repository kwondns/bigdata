# %%
import csv
import matplotlib.pyplot as plt

f = open('/content/age.csv', 'r', encoding='cp949')
data = csv.reader(f)
next(data)

result = []

for row in data :
  if '일산서구 탄현동' in row[0]:
    for i in row[3:]:
      result.append(int(i.replace(",", "")))

# 시각화를 위한 설정
# 격자 무늬 스타일로 지정 classic, dark_background, ggplot
# 적용할 수 있는 스타일 목록 확인하기 -> print(plt.style.available)
plt.figure(dpi = 200)
plt.style.use('fast')  # 격자무늬 스타일로 지정

# 시각화
plt.plot(result)
plt.show()

f.close()

# %%
import csv
import matplotlib.pyplot as plt

f = open('/content/age.csv', 'r', encoding='cp949')
data = csv.reader(f)
next(data)

result = []

for row in data :
  if '일산서구 탄현동' in row[0]:
    for i in row[3:]:
      new_i = i.replace(",", "")
      result.append(int(new_i))

print(result)
# Out:
# [398, 485, 540, 595, 509, 516, 610, 528, 532, 519, 512, 568, 494, 532, 609, 596, 621, 728, 798, 752, 770, 816, 800, 848, 821, 764, 716, 741, 662, 647, 620, 656, 618, 660, 712, 818, 830, 864, 896, 931, 789, 847, 854, 849, 977, 1047, 1076, 1187, 1165, 1120, 1161, 1011, 952, 975, 953, 879, 866, 862, 800, 732, 610, 523, 479, 438, 348, 314, 290, 218, 240, 219, 245, 254, 232, 195, 207, 225, 263, 247, 199, 213, 191, 202, 157, 153, 142, 97, 104, 68, 75, 52, 41, 39, 21, 16, 7, 8, 8, 7, 2, 2, 3]
