# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("/content/energy.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32159 entries, 0 to 32158
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   dttm             32159 non-null  datetime64[ns]
#  1   weekday          32159 non-null  object
#  2   day              32159 non-null  datetime64[ns]
#  3   month            32159 non-null  int64
#  4   time             32159 non-null  object
#  5   avg_temperature  32159 non-null  float64
#  6   min_temperature  32159 non-null  float64
#  7   max_temperature  32159 non-null  float64
#  8   wclass           32159 non-null  object
#  9   환기               32159 non-null  float64
#  10  콘센트              32159 non-null  float64
#  11  냉방               32159 non-null  float64
#  12  난방               32159 non-null  float64
#  13  조명               32159 non-null  float64
#  14  기타               32159 non-null  float64
# dtypes: datetime64[ns](2), float64(9), int64(1), object(3)
# ...

# %%
df = df.set_index("day")

# %%
df
# Out:
#                           dttm   weekday  month  ...        난방        조명        기타
# day                                              ...
# 2018-12-01 2018-12-01 00:15:00  Saturday     12  ...  1.400422  1.370104  1.943357
# 2018-12-01 2018-12-01 00:30:00  Saturday     12  ...  1.438566  1.407422  1.996293
# 2018-12-01 2018-12-01 00:45:00  Saturday     12  ...  1.400422  1.370104  1.943368
# 2018-12-01 2018-12-01 01:00:00  Saturday     12  ...  1.400422  1.370104  1.943379
# 2018-12-01 2018-12-01 01:15:00  Saturday     12  ...  1.367728  1.338117  1.898016
# ...                        ...       ...    ...  ...       ...       ...       ...
# 2019-10-31 2019-10-31 22:45:00  Thursday     10  ...  0.000000  1.033899  7.640000
# 2019-10-31 2019-10-31 23:00:00  Thursday     10  ...  0.000000  1.033899  7.640000
# 2019-10-31 2019-10-31 23:15:00  Thursday     10  ...  0.000000  0.974356  7.200000
# 2019-10-31 2019-10-31 23:30:00  Thursday     10  ...  0.000000  0.974358  7.200000
# ...

# %%
df =
