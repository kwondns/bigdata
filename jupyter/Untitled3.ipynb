# %%
import csv

with open("/content/seoul.csv", "r", encoding="cp949") as file:
    data = csv.reader(file, delimiter = ',')
    print(data)

# %%
import csv

with open("/content/seoul.csv", "r", encoding="cp949") as file:
    data = csv.reader(file)
    print(data)

    for i in data:
        print(i)

# %%
import csv

with open("/content/seoul.csv", "r", encoding="cp949") as file:
    data = csv.reader(file)
    header = next(data)
    header1= next(data)
print(header)
print(header1)
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']
# ['1907-10-01', '108', '13.5', '7.9', '20.7']

# %%
import csv

with open("/content/seoul.csv", "r", encoding="cp949") as file:
    data = csv.reader(file)
    header = next(data)
    print(header)

    for i in data:
        print(i)
        break
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']
# ['1907-10-01', '108', '13.5', '7.9', '20.7']
